# %% [markdown]
# <a href="https://colab.research.google.com/github/Antibodyy/appetizer/blob/master/imageToGradesLOL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Upload a picture of yourself, convert it to grayscale. Convert the grayscale image to a numpy array. This numpy array corresponds to the marks of students of your class
#
# Write a class which takes the numpy array generated above as an input. The class must have the following variables:
# 1. **number_of_students** (int)
# 2. **name_of_teacher** (Your name) (str)
# 3. **data** - stores the input numpy array (1-d numpy array)
# 4. **stats** - A dictionary of statistics that you will be calculating from the input. (dictionary)
# 5. **summary** - (list)
#
# The class must have the following functions:
# 1. **__init__** - It normalises the input array and scales it to 100, and stores it in the variable 'data'. It also sets the variable 'name_of_teacher'. The init function calls the functions 'set_num_students' , 'statistics_calculator'. Therefore after __init__all variables other than 'summary' are set.
#
# 2. **set_num_students** - sets the variable 'number_of_students'
#
# 3. **statistics_calculator** - calculates the mean, median, maximum, minimum, standard deviation of the marks and stores it in the form of a dictionary in the variable 'stats'
#
# 4. **organiser** - organises the data in a list in the form [name_of_teacher , number_of_students , stats], stores it in the variable 'summary' and prints it when called.

# %%
from google.colab import files
from PIL import Image

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-85df1dbb-ef68-45b5-91ce-7ac257ec6147" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85df1dbb-ef68-45b5-91ce-7ac257ec6147">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving colossaltitan.jpg to colossaltitan.jpg
# User uploaded file "colossaltitan.jpg" with length 93369 bytes

# %%
import IPython.display as display
from PIL import Image
colTitan = Image.open('colossaltitan.jpg')
greyTitan = colTitan.convert('L')
display.display(greyTitan)
# Out:
# <PIL.Image.Image image mode=L size=780x438 at 0x7F55A82EA110>

# %%
import numpy as np
marksArray2D = np.asarray(greyTitan)
marksArray = marksArray2D.reshape(-1)
abs_max = np.amax(np.abs(marksArray))
marksArrayScaled = marksArray * (100/abs_max)
marksArrayScaled = marksArrayScaled.astype('i')
# Out:
# [97 97 96 ... 68 68 69]

# %%
class Scouts:

  def set_num_students(self, data):
    self.number_of_students = data.shape[0]

  def statistics_calculator(self, data):
    self.stats = {"Mean":np.mean(data), "Median":np.median(data), 
                  "Maximum":np.max(data), "Minimum":np.min(data),
                  "Standard Deviation":np.std(data)}
      
  def __init__(self, name_of_teacher, data):
    self.name_of_teacher = name_of_teacher
    self.data = data
    self.set_num_students(data)
    self.statistics_calculator(data)

  def organizer(self):
   self.summary = [self.name_of_teacher, self.number_of_students, self.stats]
   print(self.summary)

# %%
batch1 = Scouts("Aryan Uday Kulkarni", marksArrayScaled)
batch1.organizer()
# Out:
# ['Aryan Uday Kulkarni', 341640, {'Mean': 54.29397611520899, 'Median': 52.0, 'Maximum': 100, 'Minimum': 1, 'Standard Deviation': 25.298353690666136}]
